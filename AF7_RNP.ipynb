# %% [markdown]
# <a href="https://colab.research.google.com/github/JoelHuitron/INTELIGENCIA-ARTIFICIAL/blob/JoelHuitron-patch-6/AF7_RNP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Actividad 7: Redes Neuronales Artificiales**
#
#
#
# # UANL FIME
# # Inteligencia Artificial y Redes Neuronales

# %% [markdown]
# Instrucciones.-
#
# * El estudiante entrenará un modelo de Red Neuronal Prealimentada en Google Colab por medio del lenguaje de programación Python. Este modelo usará el conjunto de datos MNIST; este conjunto de datos contiene imágenes de baja resolución con dígitos del 0 al 9 escritos a mano. El conjunto de datos es parte de la librería Keras. Más información acerca de este conjunto de datos: https://keras.io/api/datasets/mnist/
#
# * Durante el preprocesamiento de los datos, se utilizará la función “load_data()” de la librería Keras para cargar el conjunto de datos y generar los conjuntos de entrenamiento (train_data, train_labels) y de prueba (test_data, test_label). Se puede utilizar la división de datos predeterminada por esta misma función.
#
# * Se entrenará una red neuronal artificial prealimentada con los datos de entrenamiento utilizando la función “fit” de la librería scikit-learn. El estudiante propondrá una estructura de red neuronal artificial prealimentada. La función de activación en la capa de salida deberá ser softmax.
#
# * Se establecerá el tipo de función de pérdida y optimizador a utilizar. La métrica a utilizar para evaluar el proceso de entrenamiento será la exactitud (accuracy).
#
# * Utilizar la función “evaluate” para mostrar la exactitud de predicción del modelo con el conjunto de datos de prueba (test_data).
#
# * Realizar 5 diferentes predicciones con el conjunto de datos de prueba (test_data). En el resultado mostrar la predicción y el valor real.

# %%
Actividad 7: Redes Neuronales Artificiales
Joel Alonso Huitrón Varela	1967359
María Angélica Ramírez Espericueta	2009245
Nancy pamela plaza muñoz	1898628
Othilia Jimena Flores Duarte	2052999
Cristian Gael Alvarado Ayala	2005742                            HORA:N4

# %% [markdown]
# 1. Importamos librerias

# %%
# importar librerías
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.utils import to_categorical
import numpy as np
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import mnist

# %% [markdown]
# 2. Cargar el conjunto de datos MNIST

# %%
(train_data, train_labels), (test_data, test_labels) = mnist.load_data()

# %% [markdown]
# 3. Preprocesamiento de datos

# %%
# Normalizar las imágenes
train_data = train_data / 255.0
test_data = test_data / 255.0

# encoding de las etiquetas
train_labels_cat = to_categorical(train_labels, num_classes=10)
test_labels_cat = to_categorical(test_labels, num_classes=10)

# %% [markdown]
# **4. Definir, compilr, entrer y evaluar el modelo**

# %%
modelo = Sequential([
    Flatten(input_shape=(28, 28)),          # Aplanar la imagen
    Dense(128, activation='relu'),          # Capa oculta
    Dense(64, activation='relu'),           # Otra capa oculta
    Dense(10, activation='softmax')         # Capa de salida para 10 clases
])

modelo.compile(optimizer='adam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

history = modelo.fit(train_data, train_labels_cat,
                     epochs=15,
                     validation_split=0.2,
                     batch_size=32)

test_loss, test_accuracy = modelo.evaluate(test_data, test_labels_cat)
print(f"Exactitud en el conjunto: {test_accuracy:.4f}")

modelo.save("modelmnist.keras")

# Graficar precisión
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.xlabel('Época')
plt.ylabel('Precisión')
plt.title('Precisión por época')
plt.legend()
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8652 - loss: 0.4649 - val_accuracy: 0.9560 - val_loss: 0.1517
# Epoch 2/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9646 - loss: 0.1180 - val_accuracy: 0.9674 - val_loss: 0.1034
# Epoch 3/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9782 - loss: 0.0714 - val_accuracy: 0.9670 - val_loss: 0.1042
# Epoch 4/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9828 - loss: 0.0532 - val_accuracy: 0.9731 - val_loss: 0.0926
# Epoch 5/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9877 - loss: 0.0405 - val_accuracy: 0.9718 - val_loss: 0.1039
# Epoch 6/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9897 - loss: 0.0317 - val_accuracy: 0.9715 - val_loss: 0.0981
# Epoch 7/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9906 - loss: 0.0284 - val_accuracy: 0.9726 - val_loss: 0.1030
# Epoch 8/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9934 - loss: 0.0211 - val_accuracy: 0.9729 - val_loss: 0.1125
# Epoch 9/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9933 - loss: 0.0193 - val_accuracy: 0.9728 - val_loss: 0.1196
# Epoch 10/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9938 - loss: 0.0169 - val_accuracy: 0.9723 - val_loss: 0.1154
# Epoch 11/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9951 - loss: 0.0132 - val_accuracy: 0.9708 - val_loss: 0.1437
# Epoch 12/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9953 - loss: 0.0130 - val_accuracy: 0.9736 - val_loss: 0.1395
# Epoch 13/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9958 - loss: 0.0131 - val_accuracy: 0.9746 - val_loss: 0.1272
# Epoch 14/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9969 - loss: 0.0090 - val_accuracy: 0.9756 - val_loss: 0.1296
# Epoch 15/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9972 - loss: 0.0087 - val_accuracy: 0.9783 - val_loss: 0.1183
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9734 - loss: 0.1160
# Exactitud en el conjunto: 0.9790

# %% [markdown]
# **5. Predicciones**

# %%
# Cargar modelo .keras
modelo = tf.keras.models.load_model("modelmnist.keras")

# Cargar datos de prueba
(_, _), (test_data, test_labels) = mnist.load_data()

# Normalizar imágenes
test_data = test_data / 255.0

# Expandir dimensiones para incluir canal (28, 28) → (28, 28, 1)
test_data = np.expand_dims(test_data, axis=-1)

#Realizar 5 predicciones
for i in range(5):
    imagen = test_data[i:i+1]  # Imagen con batch size 1
    etiqueta_real = test_labels[i]

    pred = modelo.predict(imagen)
    clase_predicha = np.argmax(pred)

    # Mostrar resultados
    print(f"\n Imagen #{i+1}")
    print(f" Valor real: {etiqueta_real}")
    print(f" Predicción : {clase_predicha}")

    plt.imshow(np.squeeze(imagen), cmap='gray')
    plt.title(f"Predicción: {clase_predicha} | Real: {etiqueta_real}")
    plt.axis('off')
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
#
#  Imagen #1
#  Valor real: 7
#  Predicción : 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
#  Imagen #2
#  Valor real: 2
#  Predicción : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
#  Imagen #3
#  Valor real: 1
#  Predicción : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
#  Imagen #4
#  Valor real: 0
#  Predicción : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
#  Imagen #5
#  Valor real: 4
#  Predicción : 4
